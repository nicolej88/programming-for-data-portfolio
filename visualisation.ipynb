# %% [markdown]
# # Visualising the data
# ---
#
# There are a good number of libraries available containing functions for visualising data with bar charts, pie charts, line plots, box plots, scatter plots and, in some libraries, with more image based visualisations.
#
# To keep it relatively simple, we will start with matplotlib, a widely used library with a wide range of visualisation functions (pyplot functions) for data sets and mathematical equations.  It has the main functions we will use in this course:
# *  bar charts
# *  pie charts
# *  line plots
# *  box plots
# *  scatter plots
# *  histogram
#
# Each requires these things:
# 1. Select the data columns to be plotted
# 2. Prepare the data (remove null values, clean formats, etc)
# 3. Run the function for the required plot
#
# Once you have the hang of these, you can start to look at labelling, colouring, etc.
#
# In order to begin creating visualisations, you need to:
# * import **matplotlib.pyplot** as **plt**
#
# Test output for all Exercises is [here](https://docs.google.com/presentation/d/e/2PACX-1vSqdTg47YlYie7ld1QHapcbUMYiYdlIg04gN4P0OsnCWH02oRlrmsgMVXAobtgD8IiM_0tr35IsEZxl/pub?start=false&loop=false&delayms=3000)

# %% [markdown]
# #  Bar charts and Line Plots
# ---
#
# For these exercises, use the Excel data file:
#
# 'public-use-talent-migration' looking at sheet_name 'Country Migration'
# https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx?raw=true
#
# **Example**:
#
# Watch the video [here](https://drive.google.com/file/d/1eNOy7fhkB2CSfVdb66kqB66qXfoPfOpd/view?usp=sharing) - demonstration of creating a bar chart using the `matplotlib` library `pyplot`.  Then have a go at creating it yourself.

# %% [markdown]
# ### Exercise 1 - Creating a Bar chart for yearly migration
# ---
# Create a bar chart which shows the total net migration for the years 2015-2019
#
# * split the net migration columns into a new dataframe
# * create a series from the max() values of the five columns
# * create a labels variable, this time just create a list of the 5 years ['2015','2016','2017','2018','2019']
# * plot the bar chart
#
# ***Presentation tips***:
# * use plt.xlabel('Year') and plt.ylabel('Total net migration') to name your axis
# * display your bar graph with plt.show

# %%
import pandas as pd
import matplotlib.pyplot as plt

url="https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx?raw=true"

country_migration = pd.read_excel(url, sheet_name="Country Migration")

net_migration = country_migration[["net_per_10K_2015","net_per_10K_2016", "net_per_10K_2017", "net_per_10K_2018", "net_per_10K_2019"]]
maximum = net_migration[["net_per_10K_2015","net_per_10K_2016", "net_per_10K_2017", "net_per_10K_2018", "net_per_10K_2019"]].max()
display(maximum)

ser = pd.Series(data=maximum)
ser

labels=ser.keys()
labels

plt.barh(labels, ser)
plt.show()
# Out:
# net_per_10K_2015    150.68
# net_per_10K_2016    124.48
# net_per_10K_2017     87.00
# net_per_10K_2018     91.41
# net_per_10K_2019     87.71
# dtype: float64

# %% [markdown]
# ### Exercise 2 - creating a bar graph using grouped data
# ---
#
# Create a horizontal bar chart of 2019 mean immigration for each income level ('`target_country_wb_income`')
#
# * create a data variable which contains the means, grouped by '`target_country_wb_income`'
# * extract your labels (x) using the .keys() function
# * use the plt.barh(x, y) to create a horizontal bar graph
# * add labels to the axes ('Year', 'Net Migration')
# * show the plot
#
# Try using plt.bar(x,y) - can you see why horizontally is more appropriate?

# %%
mean_income = country_migration.groupby(["target_country_wb_income"]).mean()
mean_income

year_2019 = mean_income["net_per_10K_2019"]
year_2019

labels=year_2019.keys()
labels
plt.xlabel('Net Migration')
plt.ylabel('Income Level')

plt.barh(labels, year_2019)
plt.show()

# %% [markdown]
# ### Exercise 3 - Line plot of net migration
# ---
#
# Creating a line plot of mean net migration over the years 2015 to 2019
#
# * create a new dataframe containing only the five columns holding net migration
# * create a new data variable to hold the means of the five columns
# * create a labels variable to hold the keys (column headings)
# * use plt.plot(x, y) to plot your line chart
#
# ***Presentation tips:***
# Plot the chart, then add formatting, then show the plot
#
# Rotate the x-axis labels in the plot:
# `plt.xticks(rotation=45)`
#
# Show the grid:
# `plt.grid()`
#
# When all formatting has been done, show the plot:
# `plt.show()`

# %%
url="https://github.com/futureCodersSE/working-with-data/blob/main/Data%20sets/public_use-talent-migration.xlsx?raw=true"

country_migration = pd.read_excel(url, sheet_name="Country Migration")

net_migration = country_migration[["net_per_10K_2015","net_per_10K_2016", "net_per_10K_2017", "net_per_10K_2018", "net_per_10K_2019"]]
#display(net_migration)

mean_migration = net_migration[["net_per_10K_2015","net_per_10K_2016", "net_per_10K_2017", "net_per_10K_2018", "net_per_10K_2019"]].mean()

labels=mean_migration.keys()
labels
plt.xlabel('Year')
plt.ylabel('Net Migration')
plt.plot(labels, mean_migration)

plt.xticks(rotation=45)

plt.grid()

plt.show()

# %% [markdown]
# # Pie Charts, Box Plots, Scatter Plots and Histograms
# ---
#
# For the remaining exercises you will use the Psychology dataset: "https://github.com/lilaceri/Working-with-data-/blob/b157a2feceb7709cf82426932385706d65446270/Data%20Sets%20for%20code%20divisio/Positive_Psychology_2017.csv?raw=true"
#
# To get the data ready:
#
# * read csv file above and save into a new variable called `psych_data`

# %%
url="https://raw.githubusercontent.com/lilaceri/Working-with-data-/b157a2feceb7709cf82426932385706d65446270/Data%20Sets%20for%20code%20divisio/Positive_Psychology_2017.csv"
psych_data = pd.read_csv(url)
psych_data
# Out:
#     Age                                            English firstlanguage  \
# 0    24                               Your Second Language        Arabic
# 1    22                               Your Second Language        Arabic
# 2    26                               Your Second Language       Burmese
# 3    23                               Your Second Language       Chinese
# 4    25                               Your Second Language       Chinese
# 5    24                               Your Second Language       Chinese
# 6    22                               Your Second Language       Chinese
# 7    36                               Your Second Language       Chinese
# 8    22                               Your Second Language       Chinese
# 9    22                               Your Second Language       Chinese
# 10   23                               Your Second Language       Chinese
# 11   22                               Your Second Language       Chinese
# 12   26                               Your Second Language        German
# 13   24                               Your Second Language         Greek
# 14   26                               Your Second Language         Hindi
# 15   29                               Your Second Language      Japanese
# 16   34                               Your Second Language      Romanian
# 17   23                               Your Second Language        Slovak
# 18   23  First Language (or you are bilingual in it wih...           NaN
# 19   24  First Language (or you are bilingual in it wit...           NaN
# 20   23  First Language (or you are bilingual in it wit...           NaN
# 21   23  First Language (or you are bilingual in it wit...           NaN
# 22   25  First Language (or you are bilingual in it wit...           NaN
# 23   23  First Language (or you are bilingual in it wit...           NaN
# 24   27  First Language (or you are bilingual in it wit...           NaN
# 25   29  First Language (or you are bilingual in it wit...           NaN
# 26   22  First Language (or you are bilingual in it wit...           NaN
# 27   22  First Language (or you are bilingual in it wit...           NaN
# 28   29  First Language (or you are bilingual in it wit...           NaN
# 29   23  First Language (or you are bilingual in it wit...           NaN
# 30   26  First Language (or you are bilingual in it wit...           NaN
# 31   26  First Language (or you are bilingual in it wit...           NaN
# 32   22  First Language (or you are bilingual in it wit...           NaN
# 33   23  First Language (or you are bilingual in it wit...           NaN
# 34   22  First Language (or you are bilingual in it wit...           NaN
# 35   44  First Language (or you are bilingual in it wit...           NaN
# 36   74  First Language (or you are bilingual in it wit...           NaN
# 37   14  First Language (or you are bilingual in it wit...           NaN
# 38   40  First Language (or you are bilingual in it wit...           NaN
# 39   33  First Language (or you are bilingual in it wit...           NaN
# 40   26                               Your Second Language           NaN
# 41   22  First Language (or you are bilingual in it wit...           NaN
# 42   27  First Language (or you are bilingual in it wit...           NaN
# 43   24  First Language (or you are bilingual in it wit...           NaN
#
#        sex          origin  Ukresidence  MAAS  Resilliance  Wellbeing  Stress  \
# 0   Female  Outside Europe          0.0  4.60           44         26      19
# 1   Female  Outside Europe          0.0  2.60           29         10      37
# 2   Female  Outside Europe          0.0  4.13           26         20      20
# 3     Male  Outside Europe          0.0  2.77           30         16      28
# 4   Female  Outside Europe          0.0  3.80           33         27      15
# 5     Male  Outside Europe          2.0  4.40           34         25      21
# 6   Female  Outside Europe          0.0  4.30           37         22      21
# 7   Female  Outside Europe          0.5  3.33           41         25      26
# 8   Female  Outside Europe          0.0  2.60           29         20      28
# 9   Female  Outside Europe          0.0  2.40           35         24      19
# 10  Female  Outside Europe          0.0  2.47           32         24      29
# 11  Female  Outside Europe          0.0  3.93           37         29      19
# 12    Male          Europe          0.0  2.60           40         36       3
# 13  Female          Europe          0.0  4.00           42         30      32
# 14  Female  Outside Europe          2.0  4.30           41         26      17
# 15  Female  Outside Europe          0.0  4.60           33         27      14
# 16  Female          Europe          5.0  4.00           34         28      27
# 17    Male          Europe          0.0  4.10           30         26      21
# 18  Female          The UK         23.0  2.80           29          9      26
# 19  Female  Outside Europe          0.0  3.80           41         26      11
# 20  Female  Outside Europe          1.0  3.93           35         17      30
# 21  Female  Outside Europe          3.0  2.90           22          7      31
# 22    Male          Europe         19.0  4.40           35         28      21
# 23  Female          The UK         23.0  3.50           36         31      22
# 24    Male          The UK         25.0  4.40           45         31       4
# 25  Female          The UK         29.0  4.60           31         15      24
# 26  Female  Outside Europe          0.0  4.30           39         25      28
# 27  Female          Europe          0.0  3.80           39         22      24
# 28  Female          The UK         29.0  4.60           30         23      21
# 29  Female  Outside Europe          8.0  3.60           38         31      11
# 30  Female          The UK         26.0  3.50           37         17      20
# 31  Female          The UK         26.0  6.70           42         19      23
# 32  Female  Outside Europe          0.0  5.00           47         38       7
# 33  Female          The UK         11.0  2.30           30         28      26
# 34  Female          Europe          4.0  4.00           28          8      29
# 35  Female          The UK          6.0  3.47           37         23      27
# 36    Male          The UK          6.0  5.07           35         27      28
# 37    Male  Outside Europe          6.0  4.20           33         35      13
# 38  Female          The UK         30.0  3.00           40         32      17
# 39  Female          The UK         27.0  4.40           47         34       7
# 40  Female  Outside Europe          0.0  3.40           26         24      22
# 41  Female          The UK         22.0  2.90           25         30      28
# 42    Male          The UK         27.0  3.90           34         27      21
# 43      no  Outside Europe          0.0  3.30           18         13      36
#
#     selfesteem  LoC  sleep  Year
# 0           22   10     32  2017
# 1            9   16     10  2017
# 2           18   20     24  2017
# 3           20   17     10  2017
# 4           18   12     17  2017
# 5           19   13     17  2017
# 6           19    8     30  2017
# 7           18   12      4  2017
# 8           20   10     20  2017
# 9           19   17     24  2017
# 10          14   22     18  2017
# 11          17   13     29  2017
# 12          28    4     26  2017
# 13          19    5     22  2017
# 14          23    9     30  2017
# 15          24    9     16  2017
# 16          19   20     23  2017
# 17          22    9     29  2017
# 18          10   27      5  2017
# 19          21    5     12  2017
# 20          15    4     26  2017
# 21           7   21     13  2017
# 22          22    4     30  2017
# 23          21    8     27  2017
# 24          30    4     23  2017
# 25           7   16      6  2017
# 26          24   12     24  2017
# 27          28    4     12  2017
# 28          17   10     21  2017
# 29          23    6     28  2017
# 30          18   14     29  2017
# 31          14    6     28  2017
# 32          30   10     30  2017
# 33          15   19     11  2017
# 34           7   16      9  2017
# 35          17   16      7  2017
# 36          21   21     25  2017
# 37          24   13     26  2017
# 38          20    8     25  2017
# 39          23   11     30  2017
# 40          20   17     21  2017
# 41          17    9     25  2017
# 42          23   11     31  2017
# 43          15   12      7  2017

# %% [markdown]
# ### Exercise 4 - Creating a pie chart showing distribution of first languages
# ---
# Create a pie chart which shows the distribution of students who speak different languages are.
#
# To do this:
#
# * similar to Exercise 2 - create a new dataframe which groups the data by firstlanguage and contains just the 'firstlanguage' column
# * store the counts for 'firstlanguage' in a variable called language_count
# * extract your labels using the keys() function
# * plot your pie chart using plt.pie(data, labels = labels)
# * write a comment noting anything interesting about the visualisation

# %%
psych_data_2 = psych_data.groupby("firstlanguage")["firstlanguage"]
display(psych_data_2)

language_count = psych_data_2.count()
language_count

labels=language_count.keys()
labels

plt.pie(language_count, labels=labels)

plt.show()

# %% [markdown]
# **Write your comment here**:  50% of people in the data speak Chinese as their first language. Suggests first langauge is not be the best variable to use for future regression and predictions as the dataset will likely skew results.

# %% [markdown]
# ### Exercise 5 - Creating a box plot from Wellbeing data column
# ---
# A box plot is used to visualise summary infomation about a data series such as the min, max, median and quartiles.  They can show outliers (unusually high or low values that are not typical of the general distribution of values, marked on the plot as a circle or dot outside the 'whiskers').
#
# Create a box plot of the Wellbeing scores
# can
# *  split off the wellbeing column to isolate the data
# *  use plt.boxplot(data) to create boxplot and show any outliers (it will do this by default - they are shown as small circles at one, or both ends of the plot)

# %%
wellbeing = psych_data["Wellbeing"]

plt.boxplot(wellbeing)
plt.show()

# %% [markdown]
# ### Exercise 6 - Create a histogram from age data
# ---
#
# Create a histogram which shows the frequency distribution for `Wellbeing`.
#
# * split the `Wellbeing` column off to provide the data
# * plot the histogram using `plt.hist(data)`
# * add the label `Wellbeing` to the x-axis and `Frequency` to the y-axis
# * change the colours of the bars - try plt.hist(x, color = 'red')
# * show the plot (plt.show())

# %%
wellbeing = psych_data["Wellbeing"]


plt.hist(wellbeing)

plt.xlabel('Wellbeing')
plt.ylabel('Frequency')
plt.hist(wellbeing, color="red")

plt.show()

# %% [markdown]
# ### Exercise 7 - Create a scatterplot using Wellbeing and Stress data
# ---
#
# Create a scatterplot of Wellbeing and Stress data.
#
# * create **x** from the `Stress` column
# * create *y* from the `Wellbeing` column
# * use `plt.scatter(x,y)` to create a scatterplot
# * set x axis and y axis labels to '`Stress`' and '`Wellbeing`'
# * show the plot
#
# Write a short data story ( a description of the data.  What conclusion could be reached from the chart?  How confident could you be in this conclusion and why?

# %%
x=psych_data["Stress"]
y=psych_data["Wellbeing"]

plt.scatter(x,y)
plt.xlabel('Stress')
plt.ylabel('Wellbeing')
plt.show()

# %% [markdown]
# **Write your data story here**: The data in the scatter plot shows how wellbeing is effected by stress. The plot suggests that as stress increases wellbeing levels decrease. The data shows  a general trend but correlation is not very strong and other variables are likely to effect wellbeing levels.

# %% [markdown]
# # Using seaborn to create more advanced visuals
# ---
#
# Seaborn is another python package based upon matplotlib. It is useful for creating more attractive visualisations and also specialises in statistical visualisations so can often provide more insightful visualisations.
#
# In order to use seaborn use the following:
#
# ``` import seaborn as sns ```
#
# Similar to matplotlib, you can use seaborn to display all the above visualisations such as:
#
# **bar chart**
#
# `sns.barplot(x = '...', y = '..', data = '...')`
#
# **box plot**
# 1. box plot with 1 variable, landscape
# `sns.boxplot(x="...", data='...')`
# 2. boxplot with 1 variable,  portrait
# `sns.boxplot(y="...", data='...')`
# 3. box plot 2 variables, x against y
# `sns.boxplot(x="...", y="....", data='...')`
#
# **scatter plot**
#
# `sns.lmplot(x='..', y='..', data='...')`
#
# ### As well as some more complex visualisations:
#
# **scatter plot with line of best fit**
#
# `sns.regplot(x="...", y="...", data= '...')`
#
# **histogram plot (of distribution)**
#
# `sns.distplot(dataframe['column'])`
# *if you add* `,bins= ... ` *you can set the number of bins (bars) in your chart*
#
# **correlation heatmap matrix**
#
# `correlation_matrix = dataframe.corr().round(2)`
#
# `sns.heatmap(data=correlation_matrix, annot=True)`
# Use `annot = True` *to print the correlation values inside the square*
#
#
#
#
# **For the next few exercises you will continue using the positive psychology dataset**

# %% [markdown]
# ### Exercise 8 - Create a scatter plot with a line of best fit
# ---
#
# Use seaborn to create a scatterplot with a line of best fit of Wellbeing (x) and Stress (y)
# * use `sns.regplot`

# %%
import seaborn as sns

x=psych_data["Wellbeing"]
y=psych_data["Stress"]


sns.regplot(x=x, y=y, data= 'psych_data')
# Out:
# <AxesSubplot:xlabel='Wellbeing', ylabel='Stress'>

# %% [markdown]
# ### Exercise 9 - Create a box plot
# ---
# Use seaborn to create a portrait box plot of Stress data
# * use `sns.boxplot`
# * can you see any outliers?

# %%
import seaborn as sns

y = psych_data["Stress"]

sns.boxplot(y="Stress", data= psych_data)
#2 outliers
# Out:
# <AxesSubplot:ylabel='Stress'>

# %% [markdown]
# ### Exercise 10 - Correlation matrix
# ---
# Create a correlation heatmap matrix using seaborn to show the correlation coefficient (confidence the one value can predict the other - the nearer to 1, or -1, the stronger the correlation, positive or negative) between all columns in the dataframe
#
# * Set the correlation matrix into a variable using the .corr() function
# * Create a heatmap using `sns.heatmap` of the correlation matrix
# (You can add `cmap='BrBG'` to the heatmap parameter list to change the colour scheme)
#
# Explain which variables seem to be correlated fairly strongly with which other variables.

# %%
correlation_matrix = psych_data.corr().round(2)

sns.heatmap(data=correlation_matrix, annot=True, cmap='BrBG')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Describe the correlation between variables here**:
#
# Self esteem positively effects wellbeing, resilliance and sleep.
# Resilliance is positively correlated with wellbeing.
# Wellbeing is positively correlated with sleep.
#
#
# Stress negatively effects resilliance, wellbeing, self esteem.

# %% [markdown]
# # Reflection
# ----
#
# ## What skills have you demonstrated in completing this notebook?

# %% [markdown]
# Selecting data cloumns and cleaning data reading to plot. Visualising the data using diifferent functions including bar charts, pie charts, line plots, box plots, scatter plotsin matplotlib. Writing a short data story and reaching conclusion from interpreting the charts.
#
# Using seaborn to create more advanced visuals in data charts.

# %% [markdown]
# ## What caused you the most difficulty?

# %% [markdown]
# Your answer here: Plotting the first chart with appropriate labels.
